# %% [markdown]
# # Making a Filterfile for generating simulated 2-channel PPD data

# %% [markdown]
# ### Imports

# %%
from detprocess import Noise, Template
import numpy as np
import matplotlib.pyplot as plt
import cloudpickle

def twopole(t, trise, tfall, A, t0):
    thing = A * ( np.exp(-(t-t0)/tfall) - np.exp(-(t-t0)/trise) )
    return np.where(thing > 0, thing, 0)

def threepole(t, trise, tfall1, tfall2, A, B, t0):
    thing = A * ( np.exp(-(t-t0)/tfall1) - np.exp(-(t-t0)/trise) ) + B * ( np.exp(-(t-t0)/tfall2) - np.exp(-(t-t0)/trise) )
    return np.where(thing > 0, thing, 0)

def norm(x):
    return x / np.max(x)

fs = 1.25e6
trace_length_sec = .020
pretrigger_length_sec = .005
nsamp = int(fs * trace_length_sec)

tdata = np.arange(nsamp)/fs
fdata = np.fft.fftfreq(nsamp, 1/fs)

# %% [markdown]
# ### Generating Noise

# %%
def power(f, f0, n, A0):
    return A0*A0 / (1 + (f/f0)**n)**2

fig, ax = plt.subplots()

psd_Si = power(fdata, 1e4, 2, 1e-10)
psd_Si[0] = 0

psd_GaAs = power(fdata, 1e4, 2, 2e-10)
psd_GaAs[0] = 0

ax.plot(fdata, psd_GaAs, label = 'GaAs')
ax.plot(fdata, psd_Si, label = 'Si')
ax.legend()

ax.set_xscale('log')
ax.set_yscale('log')


noise = Noise()


noise.set_psd(channels = 'channel_00',
              psd = psd_GaAs,
              psd_freqs=fdata,
              pretrigger_length_msec=pretrigger_length_sec*1000)

noise.set_psd(channels = 'channel_01',
              psd = psd_Si,
              psd_freqs=fdata,
              pretrigger_length_msec=pretrigger_length_sec*1000)

noise.set_psd(channels = 'channel_02',
              psd = psd_Si,
              psd_freqs=fdata,
              pretrigger_length_msec=pretrigger_length_sec*1000)

# %%
template = Template()

fig, ax = plt.subplots()

single_template = norm(twopole(tdata, 10e-6, 100e-6, 1, 5e-3))
share_template = norm(twopole(tdata, 20e-6, 200e-6, 1, 5e-3))

ax.plot(tdata*1000, single_template)
ax.plot(tdata*1000, share_template)

ax.set_xlim(4,10)
ax.set_xlabel('Time (msec)', fontsize = 14)
ax.set_ylabel('Current (arb.)')



template.set_template(channels = ['channel_00'],
                      template = single_template,
                      sample_rate = fs,
                      pretrigger_length_msec = pretrigger_length_sec*1000,
                      tag = 'single')


template.set_template(channels = ['channel_00'],
                      template = share_template,
                      sample_rate = fs,
                      pretrigger_length_msec = pretrigger_length_sec*1000,
                      tag = 'shared')



template.set_template(channels = ['channel_01'],
                      template = single_template,
                      sample_rate = fs,
                      pretrigger_length_msec = pretrigger_length_sec*1000,
                      tag = 'single')


template.set_template(channels = ['channel_01'],
                      template = share_template,
                      sample_rate = fs,
                      pretrigger_length_msec = pretrigger_length_sec*1000,
                      tag = 'shared')



template.set_template(channels = ['channel_02'],
                      template = single_template,
                      sample_rate = fs,
                      pretrigger_length_msec = pretrigger_length_sec*1000,
                      tag = 'single')


template.set_template(channels = ['channel_02'],
                      template = share_template,
                      sample_rate = fs,
                      pretrigger_length_msec = pretrigger_length_sec*1000,
                      tag = 'shared')

# %% [markdown]
# ### dPdI

# %%
def dpdi(f, f0, n, A0):
    return A0 * (1 + (np.abs(f)/f0)**n)

fig, ax = plt.subplots()

dpdi_vals =  dpdi(fdata, 5e4, 2.5, 1e-7).astype(np.complex128)

ax.plot(fdata, dpdi_vals)
ax.set_yscale('log')
ax.set_xscale('log')

template.set_dpdi(channels = 'channel_00',
                  dpdi = dpdi_vals.astype(np.complex128),
                  dpdi_err = 0.1*dpdi_vals.astype(np.complex128),
                  dpdi_freqs = fdata,
                  poles = 3,
                  sample_rate = fs)

template.set_dpdi(channels = 'channel_01',
                  dpdi = dpdi_vals.astype(np.complex128),
                  dpdi_err = 0.1*dpdi_vals.astype(np.complex128),
                  dpdi_freqs = fdata,
                  poles = 3,
                  sample_rate = fs)

template.set_dpdi(channels = 'channel_02',
                  dpdi = dpdi_vals.astype(np.complex128),
                  dpdi_err = 0.1*dpdi_vals.astype(np.complex128),
                  dpdi_freqs = fdata,
                  poles = 3,
                  sample_rate = fs)

# %%
template.save_hdf5('1channel_GaAs.hdf5', overwrite = True)
noise.save_hdf5('1channel_GaAs.hdf5', overwrite = True)
# Out:
# INFO: Saving filter/TES data to file 1channel_GaAs.hdf5! (overwrite=True)
# INFO: Saving filter/TES data to file 1channel_GaAs.hdf5! (overwrite=True)

# %%
def singles_rate_Si(E):
    return np.where(E > 25, 0, (np.abs(E-25))**1.1)

def shared_rate_Si(E):
    return np.where(E > 50, 0, (np.abs(E-50))**1.1)

def singles_rate_GaAs(E):
    return np.where(E > 20, 0, (np.abs(E-20))**1.1)

def shared_rate_GaAs(E):
    return np.where(E > 45, 0, (np.abs(E-45))**1.1)

distribution_dict = {}

distribution_dict['Si_single'] = singles_rate_Si
distribution_dict['Si_shared'] = shared_rate_Si

distribution_dict['GaAs_single'] = singles_rate_GaAs
distribution_dict['GaAs_shared'] = shared_rate_GaAs

with open('LEE_distributions.pkl', 'wb') as f:
    cloudpickle.dump(distribution_dict, f)
